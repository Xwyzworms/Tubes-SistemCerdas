# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print(pd.__version__)
print(np.__version__)
# Out:
# 1.1.5
# 1.19.2

# %%
# Eksekusi Cell ini jika ingin generate new dataset
np.random.seed(100)
def randomizeMinuman(totalRow):
    return np.random.randint(low = 1, high = 11,
                             size= totalRow)
def randomizeMakanan(totalRow):
    return np.random.randint(low = 1, high = 11,
                            size = totalRow)
def randomizePelayanan(totalRow):
    return np.random.randint(low = 1, high = 101,
                            size = totalRow)
def createDataset():
    df = pd.DataFrame({"id":range(0,100)})
    df["NilaiMinuman"] = randomizeMinuman(len(df))
    df["NilaiMakanan"] =  randomizeMakanan(len(df))
    df["NilaiPelayananan"] = randomizePelayanan(len(df))
    return df
#createDataset().to_csv("Dataset.csv",index=False)

# %%
df = pd.read_csv("Dataset.csv")
df
# Out:
#     id  NilaiMinuman  NilaiMakanan  NilaiPelayananan
# 0    0             9             7                10
# 1    1             9             5                50
# 2    2             4             8                54
# 3    3             8             4                35
# 4    4             8            10                 4
# ..  ..           ...           ...               ...
# 95  95             6             7                21
# 96  96            10             6                 4
# 97  97             7             3                75
# 98  98             7             1                60
# 99  99             6             1                12
#
# [100 rows x 4 columns]

# %%
def fungsiTrapesium(x, a, b, c, d) :
    if (x <= a or x >= d):
        return 0
    elif (x >= a and x <= b):
        return (x - a) / (b - a)
    elif (x >= b and x <= c):
        return 1
    elif( x > c and x <= d):
        return -(x - d) / (d - c)
def fungsiSegitiga(x, a, b, c):
    if(x <= a or x >= c):
        return 0
    elif (x > a and x <= b):
        return (x - a) / (b - a)
    elif (x > b and x <= c):
        return -(x - c) / (c - b)

# %%
# Fuzzy untuk derajat keanggotaan
class Makanan():
    def __init__(self, x):
        self.valueOfX = x
    def makananEnak(self):
        return fungsiTrapesium(self.valueOfX, 6, 9, 10, 999)
    def makananSedang(self):
        return fungsiSegitiga(self.valueOfX, 4, 5, 8)
    def makananNggaEnak(self):
        return fungsiTrapesium(self.valueOfX, -999, 0 ,3, 5)
    
class Minuman():
    def __init__(self,x):
        self.valueOfX = x
    def minumanEnak(self):
        return fungsiTrapesium(self.valueOfX, 7, 9, 10, 999)
    def minumanSedang(self):
        return fungsiSegitiga(self.valueOfX, 4, 5, 8)
    def minumanNggaEnak(self):
        return fungsiTrapesium(self.valueOfX, -999, 0 , 3, 5)

class Pelayanan():
    def __init__(self, x):
        self.valueOfX = x
    def pelayananSangatBaik(self):
        return fungsiTrapesium(self.valueOfX, 80, 90 , 100, 999)
    def pelayananBaik(self):
        return fungsiTrapesium(self.valueOfX, 65, 75, 80, 90)
    def pelayananBuruk(self):
        return fungsiTrapesium(self.valueOfX, 35, 45, 75, 80)
    def pelayananSangatBuruk(self):
        return fungsiTrapesium(self.valueOfX, -999, 0, 20 ,45 )

class Kelayakan():
    
    def __init__(self,x):
        self.valueOfX = x
    def kelayakanSangatRendah(self):
        return fungsiTrapesium(self.valueOfX, -999, 0, 20 ,30)
    def kelayakanRendah(self):
        return fungsiSegitiga(self.valueOfX, 35, 55, 65)
    def kelayakanTinggi(self):
        return fungsiSegitiga(self.valueOfX, 55, 75, 85)
    def kelayakanSangatTinggi(self):
        return fungsiTrapesium(self.valueOfX, 75, 100, 999, 999)

# %%
# Plot ting
makanan = np.arange(1, 10,1)
f,(ax1,ax2,ax3) = plt.subplots(3,1,figsize=(10,8))
ax1.plot(makanan,[Makanan(x).makananNggaEnak() for x in makanan],label = "Ngga Enak")
ax2.plot(makanan, [Makanan(x).makananSedang() for x in makanan],label = "Sedang")
ax3.plot(makanan,[Makanan(x).makananEnak() for x in makanan],label="Enak")

# %%
plt.plot(makanan,[Makanan(x).makananNggaEnak() for x in makanan],label = "Ngga Enak")
plt.plot(makanan, [Makanan(x).makananSedang() for x in makanan],label = "Sedang")
plt.plot(makanan,[Makanan(x).makananEnak() for x in makanan],label="Enak")
plt.legend()

# %%
# Plot Pelayanan 
minuman = np.arange(1, 10,1)
f,(ax1,ax2,ax3) = plt.subplots(3,1,figsize=(10,8))
ax1.plot(minuman,[Minuman(x).minumanNggaEnak() for x in minuman],label = "Ngga Enak")
ax2.plot(minuman, [Minuman(x).minumanSedang() for x in minuman],label = "Sedang")
ax3.plot(minuman,[Minuman(x).minumanEnak() for x in minuman],label="Enak")

# %%
plt.plot(minuman,[Minuman(x).minumanNggaEnak() for x in minuman],label = "Ngga Enak")
plt.plot(minuman, [Minuman(x).minumanSedang() for x in minuman],label = "Sedang")
plt.plot(minuman,[Minuman(x).minumanEnak() for x in minuman],label="Enak")
plt.legend()

# %%
#Pelayanan
pelayanan= np.arange(1, 100,1)
f,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,figsize=(10,8))
ax1.plot(pelayanan,[Pelayanan(x).pelayananSangatBuruk() for x in pelayanan])
ax2.plot(pelayanan,[Pelayanan(x).pelayananBuruk() for x in pelayanan])
ax3.plot(pelayanan,[Pelayanan(x).pelayananBaik() for x in pelayanan])
ax4.plot(pelayanan,[Pelayanan(x).pelayananSangatBaik() for x in pelayanan])

# %%
pelayanan= np.arange(1, 100,1)
plt.plot(pelayanan,[Pelayanan(x).pelayananSangatBuruk() for x in pelayanan],label="Sangat buruk")
plt.plot(pelayanan,[Pelayanan(x).pelayananBuruk() for x in pelayanan],label = "Buruk")
plt.plot(pelayanan,[Pelayanan(x).pelayananBaik() for x in pelayanan],label="Baik")
plt.plot(pelayanan,[Pelayanan(x).pelayananSangatBaik() for x in pelayanan],label="Sangat Baik")
plt.legend()

# %%
kelayakan= np.arange(1, 100,1)
f,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,figsize=(10,8))
ax1.plot(kelayakan,[Kelayakan(x).kelayakanSangatRendah() for x in kelayakan])
ax2.plot(kelayakan,[Kelayakan(x).kelayakanRendah() for x in kelayakan])
ax3.plot(kelayakan,[Kelayakan(x).kelayakanTinggi() for x in kelayakan])
ax4.plot(kelayakan,[Kelayakan(x).kelayakanSangatTinggi() for x in kelayakan])

# %%
plt.plot(kelayakan,[Kelayakan(x).kelayakanSangatRendah() for x in kelayakan],label="Sangat Rendah")
plt.plot(kelayakan,[Kelayakan(x).kelayakanRendah() for x in kelayakan],label="Rendah")
plt.plot(kelayakan,[Kelayakan(x).kelayakanTinggi() for x in kelayakan],label="Tinggi")
plt.plot(kelayakan,[Kelayakan(x).kelayakanSangatTinggi() for x in kelayakan],label="Sangat Tinggi")
plt.legend()

# %%
nilaiMakanan = 4.5
MakananObj = Makanan(nilaiMakanan)
ArrPenilainFuzzy = [MakananObj.makananNggaEnak(),MakananObj.makananSedang(),MakananObj.makananEnak()]
ArrPenilainFuzzy
# Out:
# [0.25, 0.5, 0]

# %%
# 0 representasikan buruk pada makanan dan minuman, sangat buruk untuk pelayanan, sangat rendah untuk NK
# 1 representasikan sedang pada makanan dan minuman, buruk untuk pelayanan, rendah untuk NK
# 2 representasikan baik pada makanan dan minuman, baik untuk pelayanan, tinggi untuk NK
# 3 representasikan sangat baik pada pelayanan, sangat tinggi untuk NK

def RulesNgab(makanan, minuman, pelayanan):
    if (makanan == 0 and minuman == 0 and pelayanan == 0):
        return 0
    
    elif (makanan == 0 and minuman == 0 and pelayanan == 1):
        return 0
    
    elif(makanan == 0 and minuman  == 0 and pelayanan == 2 ):
        return 1
    
    elif(makanan == 0 and minuman == 0 and pelayanan == 3):
        return 1
    
    elif(makanan == 1 and minuman == 0 and pelayanan == 0):
        return 0
    
    elif(makanan == 1 and minuman == 0 and pelayanan == 1):
        return 0
   
    elif(makanan == 1 and minuman == 0 and pelayanan == 2):
        return 0
    
    elif(makanan == 1 and minuman == 0 and pelayanan == 3):
        return 1
    
    #baik / buruk
    elif(makanan == 2 and minuman == 0 and pelayanan == 0):
        return 0
    elif(makanan == 2 and minuman == 0 and pelayanan == 1):
        return 1
    elif(makanan == 2 and minuman == 0 and pelayanan == 2):
        return 1
    elif(makanan == 2 and minuman == 0 and pelayanan == 3):
        return 2
    
    # buruk/ baik
    elif(makanan == 0 and minuman ==2 and pelayanan == 0):
        return 0
    elif(makanan == 0 and minuman ==2 and pelayanan == 1):
        return 1
    elif(makanan == 0 and minuman ==2 and pelayanan == 2):
        return 1
    elif(makanan == 0 and minuman ==2 and pelayanan == 3):
        return 2
    
    
    #Buruk/sedang
    elif(makanan == 0 and minuman == 1 and pelayanan == 0):
        return 0
    elif(makanan == 0 and minuman == 1 and pelayanan == 1):
        return 0
    elif(makanan == 0 and minuman == 1 and pelayanan == 2):
        return 0
    elif(makanan == 0 and minuman == 1 and pelayanan == 3):
        return 1
    
    #Sedang / Sedang
    elif (makanan == 1 and minuman == 1 and pelayanan == 0):
        return 1
    elif (makanan == 1 and minuman == 1 and pelayanan == 1):
        return 1
    elif (makanan == 1 and minuman == 1 and pelayanan == 2):
        return 2
    elif (makanan == 1 and minuman == 1 and pelayanan == 3):
        return 2
    #Sedang / Baik 
    elif(makanan == 1 and minuman == 2 and pelayanan == 0):
        return 1
    elif(makanan == 1 and minuman == 2 and pelayanan == 1):
        return 1
    elif(makanan == 1 and minuman == 2 and pelayanan == 2):
        return 2
    elif(makanan == 1 and minuman == 2 and pelayanan == 3):
        return 3
    
    #Baik / Sedang
    elif(makanan == 2 and minuman == 1 and pelayanan == 0):
        return 1
    elif(makanan == 2 and minuman == 1 and pelayanan == 1):
        return 1
    elif(makanan == 2 and minuman == 1 and pelayanan == 2):
        return 2
    elif(makanan == 2 and minuman == 1 and pelayanan == 3):
        return 3
    
    #baik / baik
    elif(makanan == 2 and minuman == 2 and pelayanan == 0):
        return 1
    elif(makanan == 2 and minuman == 2 and pelayanan == 1):
        return 2
    elif(makanan == 2 and minuman == 2 and pelayanan == 2):
        return 3
    elif(makanan == 2 and minuman == 2 and pelayanan == 3):
        return 3

# %%
def mapMakanan(x):
    if (x == 0):
        return "nggaEnak"
    elif (x==1):
        return "sedang"
    elif (x==2):
        return "enak"

def mapPelayanan(x):
    if (x == 0):
        return "buruk"
    elif (x == 1):
        return "cukup"
    elif (x == 2):
        return "baik "
    elif (x == 3):
        return "sangat baik"
    
def mapMinuman(x):
    if (x == 0):
        return "nggaEnak"
    elif (x == 1):
        return "sedang"
    elif (x == 2):
        return "enak"
    
    
def mapKualitas(x):
    if (x == 0):
        return "sangat rendah"
    elif (x == 1):
        return "rendah"
    elif (x == 2):
        return "tinggi"
    elif (x == 3):
        return "sangat tinggi"

# %%
nilaiMakanan = 4.5
MakananObj = Makanan(nilaiMakanan)
ArrPenilainFuzzy = [MakananObj.makananNggaEnak(),MakananObj.makananSedang(),MakananObj.makananEnak()]
ArrPenilainFuzzy
# Out:
# [0.25, 0.5, 0]

# %%
def fuzzification(makananScore , minumanScore , pelayananScore):
    
    MakananObj = Makanan(makananScore)
    MinumanObj = Minuman(minumanScore)
    PelayananObj = Pelayanan(pelayananScore)
    
    makananArr = np.array([round(m,2) for m in [MakananObj.makananNggaEnak(),MakananObj.makananSedang(),
                            MakananObj.makananEnak()]])
    minumanArr = np.array([round(m,2) for m in [MinumanObj.minumanNggaEnak(),MinumanObj.minumanSedang(),
                  MinumanObj.minumanEnak()]])
    pelayananArr = np.array([round(p,2) for p in [PelayananObj.pelayananSangatBuruk(),PelayananObj.pelayananBuruk(),
                   PelayananObj.pelayananBaik(),PelayananObj.pelayananSangatBaik()]])

    hasilInference = inference(makananArr,minumanArr,pelayananArr)
    print("Hasil Inference : ")
    for i in range(len(hasilInference)):
        print(f"Nilai Kelayakan : {mapKualitas(i)} -> {hasilInference[i]}")
    
    return defuzzySugeno(*hasilInference)
def defuzzySugeno(sgtRendah, rendah, tinggi, sgtTinggi):
    totalValue = 0
    pembagi = 0
    
    if (sgtRendah != 0):
        totalValue += sgtRendah * 20
        pembagi += sgtRendah
    if (rendah != 0):
        totalValue += rendah * 55
        pembagi += rendah 
    if (tinggi != 0):
        totalValue += tinggi * 70
        pembagi += tinggi
    if(sgtTinggi != 0):
        totalValue += sgtTinggi * 100
        pembagi += sgtTinggi
    
    return totalValue / pembagi
    
def gradeResult(idxMakanan, idxMinuman, idxPelayanan,
                makananArrScore,minumanArrScore,pelayananArrScore):
    val = np.zeros(shape=(4),dtype=np.float) 
    for i in idxPelayanan:
        for j in idxMakanan:
            for z in idxMinuman:
                
                print(f"Makanan : {mapMakanan(j)} -> {makananArrScore[j]} \nMinuman : {mapMinuman(z)} -> {minumanArrScore[z]} \nPelayanan  : {mapPelayanan(i)} -> {pelayananArrScore[i] }")
                print(f"Nilai Kualitas : {mapKualitas(RulesNgab(j,z,i))} {(min(makananArrScore[j],minumanArrScore[z],pelayananArrScore[i]))}\n")
                print(min(makananArrScore[j],minumanArrScore[z],pelayananArrScore[i]))
                if val[RulesNgab(j,z,i)] < min(makananArrScore[j],minumanArrScore[z],pelayananArrScore[i]):
                    val[RulesNgab(j,z,i)] = min(makananArrScore[j],minumanArrScore[z],pelayananArrScore[i])
    return val   
def inference(makananArrScore,minumanArrScore,pelayananArrScore):
    result = np.zeros(shape=(5),dtype=np.float)

    zerosMinuman = np.where(minumanArrScore == 0)[0] # Get The content ,i.e Index zeros Minuman
    zerosMakanan = np.where(makananArrScore == 0)[0]
    zerosPelayanan = np.where(pelayananArrScore == 0)[0]
    
    if(np.size(zerosPelayanan) <= 2):
        idxPelayanan = (-pelayananArrScore).argsort()
        
        if (np.size(zerosMakanan) <= 1):
            idxMakanan = (-makananArrScore).argsort()[:2]
            
            if(np.size(zerosMinuman) <= 1):
                idxMinuman = (-minumanArrScore).argsort()[:2]
                result = gradeResult(idxMakanan, idxMinuman, idxPelayanan)
                
            
            elif(np.size(zerosMinuman) > 1):
                idxMinuman = (-minumanArrScore).argsort()[:1]
                result = gradeResult(idxMakanan, idxMinuman,
                                     idxPelayanan,makananArrScore,
                                     minumanArrScore,pelayananArrScore)
                
                
        elif (np.size(zerosMakanan) > 1 ):
            idxMakanan = (-makananArrScore).argsort()[:1]
            
            
            if(np.size(zerosMinuman) <= 1):
                idxMinuman = (-minumanArrScore).argsort()[:2]
                result = gradeResult(idxMakanan, idxMinuman, idxPelayanan)
                
            
            elif(np.size(zerosMinuman) > 1):
                idxMinuman = (-minumanArrScore).argsort()[:1]
                result = gradeResult(idxMakanan, idxMinuman,
                                     idxPelayanan,makananArrScore,
                                     minumanArrScore,pelayananArrScore)           
 
        
    elif(np.size(zerosPelayanan) >2):
        idxPelayanan = (-pelayananArrScore).argsort()[:1]
    
        if (np.size(zerosMakanan) <= 1):
            idxMakanan = (-makananArrScore).argsort()[:2]
            
            if(np.size(zerosMinuman) <= 1):
                idxMinuman = (-minumanArrScore).argsort()[:2]
                result = gradeResult(idxMakanan, idxMinuman, idxPelayanan)
                
            
            elif(np.size(zerosMinuman) > 1):
                idxMinuman = (-minumanArrScore).argsort()[:1]
                result = gradeResult(idxMakanan, idxMinuman,
                                     idxPelayanan,makananArrScore,
                                     minumanArrScore,pelayananArrScore)
                
                
        elif (np.size(zerosMakanan) > 1 ):
            idxMakanan = (-makananArrScore).argsort()[:1]
            
            
            if(np.size(zerosMinuman) <= 1):
                idxMinuman = (-minumanArrScore).argsort()[:2]
                result = gradeResult(idxMakanan, idxMinuman, idxPelayanan)
                
            
            elif(np.size(zerosMinuman) > 1):
                idxMinuman = (-minumanArrScore).argsort()[:1]
                result = gradeResult(idxMakanan, idxMinuman,
                                     idxPelayanan,makananArrScore,
                                     minumanArrScore,pelayananArrScore)           
 
    return result
fuzzification(8.5,3.2,56)
# Out:
# Makanan : enak -> 0.83
# Minuman : nggaEnak -> 0.9
# Pelayanan  : cukup -> 1
# Nilai Kualitas : rendah 0.83
#
# 0.83
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.83
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# 55.0

# %%
df
# Out:
#     id  NilaiMinuman  NilaiMakanan  NilaiPelayananan  nilaiKelayakan
# 0    0             9             7                10            55.0
# 1    1             9             5                50            55.0
# 2    2             4             8                54            55.0
# 3    3             8             4                35            20.0
# 4    4             8            10                 4            55.0
# ..  ..           ...           ...               ...             ...
# 95  95             6             7                21            55.0
# 96  96            10             6                 4            55.0
# 97  97             7             3                75            20.0
# 98  98             7             1                60            20.0
# 99  99             6             1                12            20.0
#
# [100 rows x 5 columns]

# %%
df["nilaiKelayakan"] = 0
for i in df.itertuples():
    df.loc[i[0],"nilaiKelayakan"] = fuzzification(i[3],i[2],i[4])
df
# Out:
# Makanan : sedang -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : buruk -> 1
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : buruk -> 1
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 1.0
# Minuman : enak -> 1.0
# Pelayanan  : cukup -> 1
# Nilai Kualitas : rendah 1.0
#
# 1.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 1.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 0.67
# Minuman : nggaEnak -> 0.5
# Pelayanan  : cukup -> 1
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 0.4
# Nilai Kualitas : sangat rendah 0.4
#
# 0.4
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.4
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 1
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 1
#
# 1
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 1.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : sedang -> 1.0
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1.0
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.6
# Nilai Kualitas : sangat rendah 0.6
#
# 0.6
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.6
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 0.67
# Minuman : sedang -> 0.67
# Pelayanan  : buruk -> 0.32
# Nilai Kualitas : rendah 0.32
#
# 0.32
# Makanan : enak -> 0.67
# Minuman : sedang -> 0.67
# Pelayanan  : cukup -> 0.2
# Nilai Kualitas : rendah 0.2
#
# 0.2
# Makanan : enak -> 0.67
# Minuman : sedang -> 0.67
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Makanan : enak -> 0.67
# Minuman : sedang -> 0.67
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.32
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 1
# Nilai Kualitas : rendah 1
#
# 1
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 1.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : sangat rendah 0.67
#
# 0.67
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.3
# Nilai Kualitas : sangat rendah 0.3
#
# 0.3
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.67
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.72
# Nilai Kualitas : sangat rendah 0.72
#
# 0.72
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.72
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.32
# Nilai Kualitas : sangat rendah 0.32
#
# 0.32
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.2
# Nilai Kualitas : sangat rendah 0.2
#
# 0.2
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.32
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : tinggi 0.33
#
# 0.33
# Makanan : sedang -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : baik  -> 0.9
# Nilai Kualitas : tinggi 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : baik  -> 0.9
# Nilai Kualitas : sangat tinggi 0.33
#
# 0.33
# Makanan : sedang -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : sedang -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : enak -> 1.0
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.33
# Nilai Kelayakan : sangat tinggi -> 0.33
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : buruk -> 0.52
# Nilai Kualitas : sangat rendah 0.52
#
# 0.52
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.52
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.6
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Makanan : nggaEnak -> 0.5
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.4
# Nilai Kualitas : rendah 0.4
#
# 0.4
# Makanan : nggaEnak -> 0.5
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 1.0
# Minuman : enak -> 1
# Pelayanan  : sangat baik -> 1
# Nilai Kualitas : sangat tinggi 1.0
#
# 1.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 1.0
# Makanan : enak -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : enak -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : baik  -> 0.4
# Nilai Kualitas : tinggi 0.33
#
# 0.33
# Makanan : enak -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.33
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.6
# Nilai Kualitas : rendah 0.6
#
# 0.6
# Makanan : enak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.4
# Nilai Kualitas : tinggi 0.4
#
# 0.4
# Makanan : enak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : enak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.6
# Nilai Kelayakan : tinggi -> 0.4
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1.0
# Minuman : sedang -> 1.0
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : rendah 1.0
#
# 1.0
# Makanan : enak -> 1.0
# Minuman : sedang -> 1.0
# Pelayanan  : baik  -> 0.7
# Nilai Kualitas : tinggi 0.7
#
# 0.7
# Makanan : enak -> 1.0
# Minuman : sedang -> 1.0
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 1.0
# Minuman : sedang -> 1.0
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 1.0
# Nilai Kelayakan : tinggi -> 0.7
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.67
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : sangat baik -> 1
# Nilai Kualitas : rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.67
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 0.67
# Minuman : nggaEnak -> 0.5
# Pelayanan  : buruk -> 0.32
# Nilai Kualitas : sangat rendah 0.32
#
# 0.32
# Makanan : enak -> 0.67
# Minuman : nggaEnak -> 0.5
# Pelayanan  : cukup -> 0.2
# Nilai Kualitas : rendah 0.2
#
# 0.2
# Makanan : enak -> 0.67
# Minuman : nggaEnak -> 0.5
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 0.67
# Minuman : nggaEnak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.32
# Nilai Kelayakan : rendah -> 0.2
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : cukup -> 0.8
# Nilai Kualitas : rendah 0.67
#
# 0.67
# Makanan : sedang -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : buruk -> 0.08
# Nilai Kualitas : rendah 0.08
#
# 0.08
# Makanan : sedang -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Makanan : sedang -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.67
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : buruk -> 1
# Nilai Kualitas : rendah 1
#
# 1
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 1.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 0.5
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : baik  -> 0.7
# Nilai Kualitas : sangat tinggi 0.5
#
# 0.5
# Makanan : enak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : sangat baik -> 0.3
# Nilai Kualitas : sangat tinggi 0.3
#
# 0.3
# Makanan : enak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.5
# Makanan : enak -> 1.0
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.48
# Nilai Kualitas : sangat rendah 0.48
#
# 0.48
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.48
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.4
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.4
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.24
# Nilai Kualitas : sangat rendah 0.24
#
# 0.24
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.24
# Nilai Kualitas : sangat rendah 0.24
#
# 0.24
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.33
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : cukup -> 0.6
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Makanan : nggaEnak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 0.16
# Nilai Kualitas : sangat rendah 0.16
#
# 0.16
# Makanan : nggaEnak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.16
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : cukup -> 1
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 1
# Nilai Kualitas : rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.67
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : enak -> 1
# Pelayanan  : cukup -> 0.4
# Nilai Kualitas : rendah 0.4
#
# 0.4
# Makanan : nggaEnak -> 1
# Minuman : enak -> 1
# Pelayanan  : buruk -> 0.24
# Nilai Kualitas : sangat rendah 0.24
#
# 0.24
# Makanan : nggaEnak -> 1
# Minuman : enak -> 1
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : enak -> 1
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.24
# Nilai Kelayakan : rendah -> 0.4
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 1
# Pelayanan  : sangat baik -> 0.7
# Nilai Kualitas : tinggi 0.5
#
# 0.5
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 1
# Pelayanan  : baik  -> 0.3
# Nilai Kualitas : rendah 0.3
#
# 0.3
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 1
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.3
# Nilai Kelayakan : tinggi -> 0.5
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : cukup -> 0.3
# Nilai Kualitas : sangat rendah 0.3
#
# 0.3
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : cukup -> 0.3
# Nilai Kualitas : rendah 0.3
#
# 0.3
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : buruk -> 0.28
# Nilai Kualitas : sangat rendah 0.28
#
# 0.28
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : buruk -> 0.28
# Nilai Kualitas : sangat rendah 0.28
#
# 0.28
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.3
# Nilai Kelayakan : rendah -> 0.3
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 1.0
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 1.0
#
# 1.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 1.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.67
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 1.0
# Pelayanan  : cukup -> 0.7
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 1.0
# Pelayanan  : buruk -> 0.12
# Nilai Kualitas : sangat rendah 0.12
#
# 0.12
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 1.0
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 1.0
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.12
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : sangat rendah 1
#
# 1
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 1.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 1.0
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 1.0
#
# 1.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 1.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1.0
# Minuman : enak -> 0.5
# Pelayanan  : baik  -> 1.0
# Nilai Kualitas : sangat tinggi 0.5
#
# 0.5
# Makanan : enak -> 1.0
# Minuman : enak -> 0.5
# Pelayanan  : cukup -> 0.6
# Nilai Kualitas : tinggi 0.5
#
# 0.5
# Makanan : enak -> 1.0
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 1.0
# Minuman : enak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.5
# Nilai Kelayakan : sangat tinggi -> 0.5
# Makanan : enak -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : enak -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : baik  -> 0.2
# Nilai Kualitas : tinggi 0.2
#
# 0.2
# Makanan : enak -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.2
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 1
#
# 1
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 1.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.8
# Nilai Kualitas : rendah 0.8
#
# 0.8
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.2
# Nilai Kualitas : rendah 0.2
#
# 0.2
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.8
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : tinggi 0.67
#
# 0.67
# Makanan : enak -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : baik  -> 0.1
# Nilai Kualitas : sangat tinggi 0.1
#
# 0.1
# Makanan : enak -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.67
# Nilai Kelayakan : sangat tinggi -> 0.1
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : sangat rendah 1
#
# 1
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.4
# Nilai Kualitas : rendah 0.4
#
# 0.4
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 1.0
# Nilai Kelayakan : rendah -> 0.4
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.67
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 1
#
# 1
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 1.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : sangat baik -> 0.8
# Nilai Kualitas : sangat tinggi 0.67
#
# 0.67
# Makanan : enak -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : baik  -> 0.2
# Nilai Kualitas : sangat tinggi 0.2
#
# 0.2
# Makanan : enak -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.67
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.6
# Nilai Kualitas : rendah 0.6
#
# 0.6
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.4
# Nilai Kualitas : rendah 0.4
#
# 0.4
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.6
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.67
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : rendah 0.67
#
# 0.67
# Makanan : sedang -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : baik  -> 0.1
# Nilai Kualitas : tinggi 0.1
#
# 0.1
# Makanan : sedang -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : sedang -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.67
# Nilai Kelayakan : tinggi -> 0.1
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : sangat baik -> 0.8
# Nilai Kualitas : sangat tinggi 0.67
#
# 0.67
# Makanan : sedang -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : baik  -> 0.2
# Nilai Kualitas : tinggi 0.2
#
# 0.2
# Makanan : sedang -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : sedang -> 0.67
# Minuman : enak -> 1.0
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.2
# Nilai Kelayakan : sangat tinggi -> 0.67
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 0.5
# Pelayanan  : baik  -> 1.0
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 0.5
# Pelayanan  : cukup -> 0.6
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 0.5
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : cukup -> 0.5
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : cukup -> 0.5
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : sedang -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : buruk -> 0.2
# Nilai Kualitas : rendah 0.2
#
# 0.2
# Makanan : enak -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : buruk -> 0.2
# Nilai Kualitas : rendah 0.2
#
# 0.2
# Makanan : sedang -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Makanan : sedang -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.32
# Nilai Kualitas : sangat rendah 0.32
#
# 0.32
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.2
# Nilai Kualitas : sangat rendah 0.2
#
# 0.2
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.32
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : enak -> 1
# Pelayanan  : buruk -> 0.36
# Nilai Kualitas : sangat rendah 0.36
#
# 0.36
# Makanan : nggaEnak -> 1
# Minuman : enak -> 1
# Pelayanan  : cukup -> 0.1
# Nilai Kualitas : rendah 0.1
#
# 0.1
# Makanan : nggaEnak -> 1
# Minuman : enak -> 1
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : enak -> 1
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.36
# Nilai Kelayakan : rendah -> 0.1
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 0.5
# Pelayanan  : sangat baik -> 1
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1
# Minuman : sedang -> 0.33
# Pelayanan  : buruk -> 0.72
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 0.5
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : buruk -> 1
# Nilai Kualitas : rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.67
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : cukup -> 0.5
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : cukup -> 0.5
# Nilai Kualitas : tinggi 0.33
#
# 0.33
# Makanan : sedang -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 0.2
# Nilai Kualitas : rendah 0.2
#
# 0.2
# Makanan : enak -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 0.2
# Nilai Kualitas : rendah 0.2
#
# 0.2
# Makanan : sedang -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Makanan : sedang -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : sangat tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.33
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : sangat baik -> 0.8
# Nilai Kualitas : tinggi 0.33
#
# 0.33
# Makanan : sedang -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : baik  -> 0.2
# Nilai Kualitas : tinggi 0.2
#
# 0.2
# Makanan : sedang -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : sedang -> 1.0
# Minuman : sedang -> 0.33
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.33
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : baik  -> 1.0
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : baik  -> 1.0
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 0.5
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.33
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 0.67
# Minuman : enak -> 1
# Pelayanan  : baik  -> 1
# Nilai Kualitas : sangat tinggi 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.67
# Makanan : enak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 1
# Nilai Kualitas : tinggi 1
#
# 1
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 1.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 0.67
# Minuman : sedang -> 1.0
# Pelayanan  : cukup -> 1
# Nilai Kualitas : rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.67
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : sedang -> 1.0
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.67
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 0.44
# Nilai Kualitas : sangat rendah 0.44
#
# 0.44
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.44
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : sedang -> 0.33
# Pelayanan  : buruk -> 1
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.33
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.33
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.9
# Nilai Kualitas : rendah 0.9
#
# 0.9
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.1
# Nilai Kualitas : rendah 0.1
#
# 0.1
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.9
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : buruk -> 0.84
# Nilai Kualitas : sangat rendah 0.84
#
# 0.84
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.84
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 1
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 1
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.6
# Nilai Kualitas : rendah 0.6
#
# 0.6
# Makanan : enak -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.16
# Nilai Kualitas : sangat rendah 0.16
#
# 0.16
# Makanan : enak -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Makanan : enak -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : tinggi 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.16
# Nilai Kelayakan : rendah -> 0.6
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : sedang -> 0.33
# Pelayanan  : baik  -> 1.0
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Makanan : nggaEnak -> 0.5
# Minuman : sedang -> 0.33
# Pelayanan  : cukup -> 0.4
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Makanan : nggaEnak -> 0.5
# Minuman : sedang -> 0.33
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : sedang -> 0.33
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.33
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : sedang -> 0.33
# Pelayanan  : cukup -> 1
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : sedang -> 0.33
# Pelayanan  : cukup -> 1
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 1.0
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 1.0
#
# 1.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 1.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : enak -> 1.0
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 0.76
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.52
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.52
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.33
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 0.5
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : cukup -> 0.4
# Nilai Kualitas : sangat rendah 0.4
#
# 0.4
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : buruk -> 0.24
# Nilai Kualitas : sangat rendah 0.24
#
# 0.24
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : baik  -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.4
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : baik  -> 0.9
# Nilai Kualitas : sangat rendah 0.9
#
# 0.9
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : sangat baik -> 0.1
# Nilai Kualitas : rendah 0.1
#
# 0.1
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.9
# Nilai Kelayakan : rendah -> 0.1
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.8
# Nilai Kualitas : rendah 0.67
#
# 0.67
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.2
# Nilai Kualitas : sangat rendah 0.2
#
# 0.2
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : sedang -> 0.67
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.2
# Nilai Kelayakan : rendah -> 0.67
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : baik  -> 0.5
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : sangat baik -> 0.5
# Nilai Kualitas : rendah 0.5
#
# 0.5
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 1.0
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.5
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : nggaEnak -> 0.5
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : enak -> 0.5
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 0.5
# Minuman : enak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.5
#
# 0.5
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.5
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : sangat baik -> 0.6
# Nilai Kualitas : rendah 0.6
#
# 0.6
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : baik  -> 0.4
# Nilai Kualitas : rendah 0.4
#
# 0.4
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : cukup -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.6
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : nggaEnak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 1
#
# 1
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 1.0
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : buruk -> 0.96
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Makanan : enak -> 0.33
# Minuman : sedang -> 0.67
# Pelayanan  : buruk -> 0.96
# Nilai Kualitas : rendah 0.33
#
# 0.33
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.33
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : sedang -> 0.67
# Minuman : enak -> 1
# Pelayanan  : buruk -> 1
# Nilai Kualitas : rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.0
# Nilai Kelayakan : rendah -> 0.67
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.33
# Pelayanan  : cukup -> 1.0
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.33
# Pelayanan  : baik  -> 1.0
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.33
# Pelayanan  : buruk -> 0.0
# Nilai Kualitas : sangat rendah 0.0
#
# 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.33
# Pelayanan  : sangat baik -> 0.0
# Nilai Kualitas : rendah 0.0
#
# 0.0
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.33
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.33
# Pelayanan  : cukup -> 1
# Nilai Kualitas : sangat rendah 0.33
#
# 0.33
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.33
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
# Makanan : nggaEnak -> 1
# Minuman : sedang -> 0.67
# Pelayanan  : buruk -> 1
# Nilai Kualitas : sangat rendah 0.67
#
# 0.67
# Hasil Inference :
# Nilai Kelayakan : sangat rendah -> 0.67
# Nilai Kelayakan : rendah -> 0.0
# Nilai Kelayakan : tinggi -> 0.0
# Nilai Kelayakan : sangat tinggi -> 0.0
#     id  NilaiMinuman  NilaiMakanan  NilaiPelayananan  nilaiKelayakan
# 0    0             9             7                10            55.0
# 1    1             9             5                50            55.0
# 2    2             4             8                54            55.0
# 3    3             8             4                35            20.0
# 4    4             8            10                 4            55.0
# ..  ..           ...           ...               ...             ...
# 95  95             6             7                21            55.0
# 96  96            10             6                 4            55.0
# 97  97             7             3                75            20.0
# 98  98             7             1                60            20.0
# 99  99             6             1                12            20.0
#
# [100 rows x 5 columns]

# %%
pd.set_option("max_rows",None)
df.sort_values(by=["nilaiKelayakan"],ascending=False)
# Out:
#     id  NilaiMinuman  NilaiMakanan  NilaiPelayananan  nilaiKelayakan
# 50  50             9             8                88      100.000000
# 27  27             8            10                83      100.000000
# 17  17            10             5                93      100.000000
# 67  67            10             8                80      100.000000
# 55  55             9             6                88       93.103448
# 42  42             8             9                77       85.000000
# 14  14             9             7                74       75.000000
# 46  46             9             8                66       73.896104
# 68  68             1            10                93       70.000000
# 65  65             7             5                88       70.000000
# 35  35            10             4                87       64.375000
# 64  64             8             7                40       62.500000
# 18  18             7             9                69       62.500000
# 20  20             5             9                72       61.176471
# 19  19             3            10                84       61.000000
# 43  43             7             9                67       60.660377
# 53  53             5             6                66       56.948052
# 61  61             7            10                27       55.000000
# 73  73             7             6                16       55.000000
# 78  78             8             7                 9       55.000000
# 81  81             7             7                48       55.000000
# 95  95             6             7                21       55.000000
# 57  57             6             7                40       55.000000
# 0    0             9             7                10       55.000000
# 24  24             5             6                43       55.000000
# 93  93             1             2                86       55.000000
# 69  69             5             8                53       55.000000
# 4    4             8            10                 4       55.000000
# 8    8             6             8                37       55.000000
# 9    9             3             2                94       55.000000
# 63  63             5             6                 5       55.000000
# 25  25             5            10                14       55.000000
# 60  60             4             6               100       55.000000
# 83  83             8             9                26       55.000000
# 51  51             2             2                84       55.000000
# 1    1             9             5                50       55.000000
# 45  45             1             3                88       55.000000
# 16  16             1             4                86       55.000000
# 75  75             3             2                89       55.000000
# 22  22             6             3                94       55.000000
# 31  31             8             1                54       55.000000
# 2    2             4             8                54       55.000000
# 32  32             1             6                94       55.000000
# 96  96            10             6                 4       55.000000
# 39  39             9             4                42       48.225806
# 79  79             2             8                41       47.631579
# 88  88             3             6                88       46.954023
# 30  30             8             3                41       46.515152
# 34  34            10             3                39       41.875000
# 66  66             4             7                75       37.500000
# 29  29             2             7                39       37.500000
# 56  56             4             3                77       37.500000
# 36  36             4             7                38       37.500000
# 89  89             5             2                85       37.500000
# 23  23             4             8                37       33.461538
# 47  47             3             3                69       30.000000
# 59  59            10             2                36       27.608696
# 87  87             5             1                81       23.500000
# 94  94             1             1                20       20.000000
# 97  97             7             3                75       20.000000
# 76  76             5             1                24       20.000000
# 77  77             3             4                60       20.000000
# 98  98             7             1                60       20.000000
# 92  92            10             4                16       20.000000
# 86  86             6             1                39       20.000000
# 85  85             4             6                11       20.000000
# 82  82             1             5                46       20.000000
# 84  84             3             7                32       20.000000
# 91  91             8             3                18       20.000000
# 80  80             7             4                78       20.000000
# 74  74             7             2                18       20.000000
# 3    3             8             4                35       20.000000
# 90  90             4             4                61       20.000000
# 62  62             4             3                20       20.000000
# 5    5             1             3                12       20.000000
# 72  72             8             3                34       20.000000
# 26  26             4             1                49       20.000000
# 28  28             2             9                33       20.000000
# 33  33             3             4                15       20.000000
# 37  37             3             5                 1       20.000000
# 38  38             6             2                60       20.000000
# 40  40             2             2                45       20.000000
# 41  41             1             5                20       20.000000
# 21  21             2             6                62       20.000000
# 44  44             3             3                14       20.000000
# 15  15             5             3                32       20.000000
# 48  48             6             2                55       20.000000
# 49  49             2             3                 1       20.000000
# 52  52             6             1                11       20.000000
# 13  13             1             1                37       20.000000
# 54  54             3             4                 3       20.000000
# 12  12             2             4                53       20.000000
# 11  11             3            10                27       20.000000
# 58  58             1             2                37       20.000000
# 10  10             3             6                68       20.000000
# 7    7             3             9                30       20.000000
# 6    6             5             4                50       20.000000
# 70  70             5             4                45       20.000000
# 71  71             6             1                14       20.000000
# 99  99             6             1                12       20.000000
